# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1ORlqNeY3OnD7nHNDJ_NTN93QvyurvZvh/view?usp=sharing"

# %%
id = url.split("/")[-2]
id
# Out:
# '1ORlqNeY3OnD7nHNDJ_NTN93QvyurvZvh'

# %%
prefix_url = "https://drive.google.com/uc?/export=download&id="

# %%
gdown.download(prefix_url+id, "fsd.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1ORlqNeY3OnD7nHNDJ_NTN93QvyurvZvh
# To: /Volumes/Macintosh/mlflow-dvc-food-spoilage-detector/notebooks/fsd.zip
# 100%|██████████| 946/946 [00:00<00:00, 1.30MB/s]
# 'fsd.zip'
